# %%
# !pip install selenium webdriver_manager BeautifulSoup4
# !pip install chromedriver_autoinstaller requests mysql-connector-python
# Out:
# Requirement already satisfied: selenium in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (4.31.0)
# Requirement already satisfied: webdriver_manager in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (4.0.2)
# Requirement already satisfied: BeautifulSoup4 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (4.13.3)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.3.0)
# Requirement already satisfied: trio~=0.17 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: outcome in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: requests in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from webdriver_manager) (2.32.3)
# Requirement already satisfied: python-dotenv in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from webdriver_manager) (1.1.0)
# Requirement already satisfied: packaging in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from webdriver_manager) (24.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from BeautifulSoup4) (2.6)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from requests->webdriver_manager) (3.4.1)
# Requirement already satisfied: chromedriver_autoinstaller in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (0.6.4)
# Requirement already satisfied: requests in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: mysql-connector-python in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (9.3.0)
# Requirement already satisfied: packaging>=23.1 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from chromedriver_autoinstaller) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hyundonglee/.pyenv/versions/week3_3/lib/python3.11/site-packages (from requests) (2025.1.31)

# %%
import re
import os
import time
import logging
import subprocess
import mysql.connector
from selenium import webdriver
import chromedriver_autoinstaller
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from datetime import datetime, timedelta

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')
chromedriver_autoinstaller.install()

driver = webdriver.Chrome(options=chrome_options)

# %%
db_config = {
	'host': 'localhost',
	'user': 'root',
	'password': '1234',
	'database': 'news_sentiment_db'
}

def connect_db():
		return mysql.connector.connect(**db_config)

connect_db()

# %%
KEYWORDS = ["SKT", "해킹", "유심"]
PUBLISHER = ["연합뉴스", "뉴시스", "서울경제", "데일리안", "뉴스1", "디지털데일리", "한국경제", "파이낸셜뉴스"]

# %%
# 로그 디렉토리 생성
log_dir = "logs"
os.makedirs(log_dir, exist_ok=True)

# Logger 설정
logger = logging.getLogger("comment_logger")
logger.setLevel(logging.INFO)

# 중복 핸들러 방지
if not logger.handlers:
    file_handler = logging.FileHandler(
        os.path.join(log_dir, "comments.log"), encoding="utf-8"
    )
    formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
    file_handler.setFormatter(formatter)

    logger.addHandler(file_handler)

# %%
def save_articles_to_db(articles):
    conn = connect_db()
    cursor = conn.cursor()
    sql = """
        INSERT INTO news_articles (article_id, title, summary, publisher, publish_date, url, comment_count, collected_at)
        VALUES (%s, %s, %s, %s, %s, %s, %s, NOW())
    """
    cursor.executemany(
        sql,
        [
            (
                article["article_id"],
                article["title"],
                article["summary"],
                article["publisher"],
                article["publish_date"],
                article["url"],
                article["comment_count"],
            )
            for article in articles
        ],
    )
    conn.commit()
    conn.close()

def save_comments_to_db(article_id, comments):
    conn = connect_db()
    cursor = conn.cursor()
    sql = """
        INSERT INTO news_comments (comment_id, article_id, nickname, content, like_count, dislike_count, comment_date, collected_at)
        VALUES (%s, %s, %s, %s, %s, %s, %s, NOW())
    """
    cursor.executemany(
        sql,
        [
            (
                c["comment_id"],  # 댓글 ID
                article_id,  # 기사 ID
                c["nickname"],
                c["content"],
                c["like_count"],
                c["dislike_count"],
                c["comment_date"],
            )
            for c in comments if c
        ],
    )
    conn.commit()
    conn.close()

# %%
# 기사 목록 더보기 클릭
def click_more_article():
    while True:
        try:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(5)
            more_btn = driver.find_element(
                By.CSS_SELECTOR,
                "#newsct > div.section_latest > div > div.section_more > a",
            )
            more_btn.click()
            logger.info("기사 더보기 클릭 성공")
            time.sleep(3)
        except Exception:
            logger.info("더 이상 기사 더보기 버튼이 없습니다.")
            break


# 기사 내 댓글 버튼 클릭
def click_to_comment():
    try:
        button = driver.find_element(By.CSS_SELECTOR, "a#comment_count")
        button.click()
        logger.info("댓글 버튼 클릭 성공!")
        time.sleep(10)
    except Exception:
        logger.warning("댓글 버튼을 찾을 수 없습니다.")


# 댓글 모음 내 더보기 클릭
def click_more_comment():
    while True:
        try:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(5)
            more_btn = driver.find_element(By.CSS_SELECTOR, "a.u_cbox_btn_more")
            more_btn.click()
            logger.info("댓글 더보기 클릭 성공")
            time.sleep(3)
        except Exception:
            logger.info("더 이상 댓글 더보기 버튼이 없습니다.")
            break


# 대댓글 보기 버튼
def click_child_comment_button():
    reply_count_tag_list = driver.find_elements(By.CSS_SELECTOR, "a.u_cbox_btn_reply")
    for reply_count_tag in reply_count_tag_list:
        try:
            reply_cnt_span = reply_count_tag.find_element(
                By.CSS_SELECTOR, "span.u_cbox_reply_cnt"
            )
            reply_count = int(reply_cnt_span.text.strip())

            if reply_count > 0:
                driver.execute_script("arguments[0].click();", reply_count_tag)
                logger.info(f"대댓글 {reply_count}개 버튼 클릭 성공")
                time.sleep(3)
        except Exception as e:
            logger.warning(f"대댓글 클릭 중 에러: {e}")
            continue

# %%
# def parse_publish_date(raw_date_str):
#     try:
#         match = re.match(r'(\d+)일전', raw_date_str)
#         if match:
#             days_ago = int(match.group(1))
#             return (datetime.now() - timedelta(days=days_ago)).date()

#         match = re.match(r'(\d{4})\.(\d{2})\.(\d{2})\.', raw_date_str)
#         if match:
#             year, month, day = map(int, match.groups())
#             return datetime(year, month, day).date()

#         print("날짜 형식 미매칭:", raw_date_str)
#         return None

#     except Exception as e:
#         print("날짜 파싱 실패:", raw_date_str, e)
#         return None


def convert_comment_date(raw_date: str) -> str:
    # '2025-05-08T22:27:22+0900' ➝ '2025-05-08 22:27:22'
    dt = datetime.strptime(raw_date, "%Y-%m-%dT%H:%M:%S%z")
    return dt.strftime("%Y-%m-%d %H:%M:%S")

# %%
# 기사 목록 크롤링
def get_article_data(article, publish_date):
    article_data = {}

    try:
        article_data["title"] = article.find_element(
            By.CSS_SELECTOR, "a.sa_text_title > strong.sa_text_strong"
        ).text.strip()
        article_data["summary"] = article.find_element(
            By.CSS_SELECTOR, "div.sa_text_lede"
        ).text.strip()
        article_data["url"] = article.find_element(
            By.CSS_SELECTOR, "a.sa_text_title"
        ).get_attribute("href")
        article_data["publisher"] = article.find_element(
            By.CSS_SELECTOR, "div.sa_text_press"
        ).text.strip()
        article_data["publish_date"] = publish_date

        # 기사 날짜 저장 시 사용하려고 했지만, ~일 전으로 뜨는 경우 값이 굳이 계산이 필요 없을 것 같아서 파라미터로 넘기는 날짜를 사용
        # raw_date = article.find_element(By.CSS_SELECTOR, 'div.sa_text_datetime > b').text.strip()
        # article_data['publish_date'] = parse_publish_date(raw_date)

        # https://n.news.naver.com/mnews/article/003/0013227763 ➔ 0030013227763를 Primary Key로 사용
        try:
            parts = article_data["url"].split("/")
            press_id = parts[-2]  # '003'
            article_seq = parts[-1]  # '0013227763'
            article_id = press_id + article_seq  # '0030013227763'
            article_data["article_id"] = article_id
            logger.info(f"기사 ID 추출 성공: {article_id}")
        except Exception as e:
            logger.warning(f"article_id 추출 실패: {e}")
            article_data["article_id"] = None

        try:
            comment_element = article.find_element(
                By.CSS_SELECTOR, "div.sa_text_info_right > a.sa_text_cmt"
            )
            if comment_element.is_displayed():
                comment_text = comment_element.text.strip()
                comment_number = int("".join(filter(str.isdigit, comment_text)))
                article_data["comment_count"] = comment_number
                logger.info(f"댓글 수 추출 성공: {comment_number}")
            else:
                article_data["comment_count"] = 0
                logger.info("댓글 수 없음")
        except Exception as e:
            article_data["comment_count"] = 0
            logger.warning(f"댓글 수 추출 실패: {e}")

        return article_data

    except Exception as e:
        logger.error(f"기사 데이터 추출 중 오류 발생: {e}")
        return None

# %%
# 댓글 데이터 크롤링
def get_comment_data(comment_element, article_id):
    comment_data = {}

    try:
        data_info = comment_element.get_attribute("data-info")
        
        comment_no = data_info.split("commentNo:'")[1].split("'")[0]
        nickname = comment_element.find_element(
            By.CSS_SELECTOR, "span.u_cbox_nick"
        ).text.strip()
        content_tag = comment_element.find_element(
            By.CSS_SELECTOR, "span.u_cbox_contents"
        )
        content = content_tag.text.strip()
        comment_time = comment_element.find_element(
            By.CSS_SELECTOR, "span.u_cbox_date"
        ).get_attribute("data-value")
        comment_time = convert_comment_date(comment_time)
        like_count = int(
            comment_element.find_element(By.CSS_SELECTOR, "em.u_cbox_cnt_recomm").text
        )
        dislike_count = int(
            comment_element.find_element(By.CSS_SELECTOR, "em.u_cbox_cnt_unrecomm").text
        )

        comment_data = {
            "comment_id": comment_no,
            "article_id": article_id,
            "nickname": nickname,
            "content": content,
            "like_count": like_count,
            "dislike_count": dislike_count,
            "comment_date": comment_time,
        }

        return comment_data

    except Exception as e:
        logger.error(f"에러 발생: {e}")
        return None, None

# %%
def open_comment_page(url_input, article_id):
    comment_to_save = []

    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[1])
    driver.get(url_input)
    time.sleep(3)

    click_to_comment()
    click_more_comment()
    click_child_comment_button()

    comment_list = driver.find_elements(By.CSS_SELECTOR, "li.u_cbox_comment")
    for comment_element in comment_list:
        # 댓글 내용이 있는지 확인
        delete_elements = comment_element.find_elements(By.CSS_SELECTOR, 'span.u_cbox_delete_contents')
        if delete_elements and (
            "작성자에 의해 삭제된 댓글입니다." in delete_elements[0].text
            or "작성자에 의해 삭제된 답글입니다." in delete_elements[0].text
            or "정보통신망법에 따른 권리침해 요청이 있어, 게시중단 되었습니다." in delete_elements[0].text
        ):
            logger.info(f"[{article_id}] 댓글/답글 본문 없음, 건너뜀")
            continue
        cleanbot_elements = comment_element.find_elements(By.CSS_SELECTOR, 'span.u_cbox_cleanbot_contents')
        if cleanbot_elements:
            logger.info(f"[{article_id}] 클린봇 필터된 댓글 감지, 건너뜀")
            continue

        comment_data = get_comment_data(comment_element, article_id)
        if comment_data:
            comment_to_save.append(comment_data)
            
    save_comments_to_db(article_id, comment_to_save)

    driver.close()
    driver.switch_to.window(driver.window_handles[0])

# %%
def crawl_by_date(date_str):
    search_url = f"https://news.naver.com/breakingnews/section/105/732?date={date_str}"
    driver.get(search_url)
    logger.info(f"크롤링 시작: {search_url}")
    time.sleep(2)

    click_more_article()

    data_to_save_article = []
    articles = driver.find_elements(By.CSS_SELECTOR, "li.sa_item")
    logger.info(f"총 {len(articles)}개의 기사 로드 완료")

    for art in articles:
        article_data = get_article_data(art, date_str)

        if not article_data:
            logger.warning(f"기사 데이터 추출 실패: {art}")
            continue

        if not any(k in (article_data['title'] + article_data['summary']) for k in KEYWORDS):
            logger.info(f"키워드 필터링 제외: {article_data['title']}")
            continue

        if article_data['publisher'] not in PUBLISHER:
            logger.info(f"출판사 필터링 제외: {article_data['publisher']}")
            continue

        data_to_save_article.append(article_data)

    if data_to_save_article:
        logger.info(f"{len(data_to_save_article)}개의 기사가 필터링되어 저장됩니다.")
        save_articles_to_db(data_to_save_article)

    for article in data_to_save_article:
        if (article['comment_count'] > 0):
            open_comment_page(article['url'], article['article_id'])

def run_crawler_daily():
    today = datetime.today()
    yesterday = today - timedelta(days=1)
    date_str = yesterday.strftime('%Y%m%d')
    logger.info(f"어제 날짜({date_str})로 크롤링 시작")
    crawl_by_date(date_str)

# 처음 크롤링 시 코드 실행 날짜의 하루 전까지 크롤링
def run_crawler_from_april_22():
    start_date = datetime.strptime("2025-05-14", "%Y-%m-%d")
    end_date = datetime.today() - timedelta(days=1)  # 어제까지

    current_date = start_date
    while current_date <= end_date:
        date_str = current_date.strftime("%Y%m%d")
        try:
            logger.info(f"{date_str} 날짜로 크롤링 시작")
            crawl_by_date(date_str)
        except Exception as e:
            logger.error(f"{date_str} 날짜 크롤링 실패: {e}")
        current_date += timedelta(days=1)

# %%
def dump_mysql_database():
    now = datetime.now().strftime("%Y%m%d")
    backup_file = f"backups/backup_{now}.sql"

    os.makedirs("backups", exist_ok=True)

    try:
        result = subprocess.run(
            [
                "docker",
                "exec",
                "data_science_introduction_mysql",
                "mysqldump",
                "-u",
                "root",
                "-p1234",
                "news_sentiment_db",
            ],
            capture_output=True,
            text=True,
        )

        if result.returncode == 0:
            with open(backup_file, "w") as f:
                f.write(result.stdout)
            print(f"MySQL 백업 성공: {backup_file}")
        else:
            print(f"백업 실패: {result.stderr}")
    except Exception as e:
        print(f"백업 중 예외 발생: {e}")

# %%
def main():
	# run_crawler_daily()
	run_crawler_from_april_22()

if __name__ == "__main__":
	try:
		main()
	finally:
		dump_mysql_database()
		logging.shutdown()
# Out:
# INFO:comment_logger:20250422 날짜로 크롤링 시작
# INFO:comment_logger:크롤링 시작: https://news.naver.com/breakingnews/section/105/732?date=20250422
# INFO:comment_logger:기사 더보기 클릭 성공
# INFO:comment_logger:더 이상 기사 더보기 버튼이 없습니다.
# INFO:comment_logger:총 55개의 기사 로드 완료
# INFO:comment_logger:기사 ID 추출 성공: 1380002195110
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 법무법인 민후, 개인정보 분야 전문가 박영수 변호사 영입
# INFO:comment_logger:기사 ID 추출 성공: 0140005339690
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 2025 정보통신 유공 ‘대통령 표창’ 수상
# INFO:comment_logger:기사 ID 추출 성공: 0300003305904
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:출판사 필터링 제외: 전자신문
# INFO:comment_logger:기사 ID 추출 성공: 0010015345379
# INFO:comment_logger:댓글 수 추출 성공: 30
# INFO:comment_logger:기사 ID 추출 성공: 0030013199462
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "가상자산 사기피해 돈 찾아드려요"…KISA 사칭 피싱 주의보
# INFO:comment_logger:기사 ID 추출 성공: 0030013199434
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 조규곤 파수 대표 "AI는 자신감 넘치는 인턴…제약과 과제 명확하게 인식해야"
# INFO:comment_logger:기사 ID 추출 성공: 0010015345367
# INFO:comment_logger:댓글 수 추출 성공: 10
# INFO:comment_logger:키워드 필터링 제외: 중앙선관위, '6·3 대선' 대비 보안자문회의 개최
# INFO:comment_logger:기사 ID 추출 성공: 0150005122547
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0110004477079
# INFO:comment_logger:댓글 수 추출 성공: 200
# INFO:comment_logger:기사 ID 추출 성공: 0300003305894
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 에브리존 '화이트디펜더 서버', KT클라우드 마켓플레이스 입점
# INFO:comment_logger:기사 ID 추출 성공: 4210008208318
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 파수 AI모델 ELLM …"상거래 대신하는 에이전틱 AI 사고 예방"
# INFO:comment_logger:기사 ID 추출 성공: 0110004477051
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0300003305880
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: “기술-법률 만났다”…스틸리언-세종, 디지털금융 보안 리스크 대응 '맞손'
# INFO:comment_logger:기사 ID 추출 성공: 1380002195098
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 조규곤 파수 대표 “새로운 워크포스로 AI 부상, 프라이빗 LLM 전략 필요”
# INFO:comment_logger:기사 ID 추출 성공: 1380002195097
# INFO:comment_logger:댓글 수 추출 성공: 10
# INFO:comment_logger:기사 ID 추출 성공: 0300003305855
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:출판사 필터링 제외: 전자신문
# INFO:comment_logger:기사 ID 추출 성공: 0030013199165
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013199164
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013199160
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013199159
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013199156
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013199155
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013199154
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1380002195096
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: TLS 인증서 수명 47일로 단축…'자동 관리' 최대 과제로
# INFO:comment_logger:기사 ID 추출 성공: 0300003305818
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 정보통신 유공 '대통령 표창' 수상
# INFO:comment_logger:기사 ID 추출 성공: 0300003305791
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지니언스, 'RSAC 2025'서 EDR 등 3대 솔루션 선보인다
# INFO:comment_logger:기사 ID 추출 성공: 0140005339503
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 한싹, SSL 가시성 솔루션 ‘오스가드’ 출시
# INFO:comment_logger:기사 ID 추출 성공: 0310000926492
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 2025 정보통신 유공 '대통령 표창' 수상
# INFO:comment_logger:기사 ID 추출 성공: 0030013198106
# INFO:comment_logger:댓글 수 추출 성공: 50
# INFO:comment_logger:기사 ID 추출 성공: 4210008207080
# INFO:comment_logger:댓글 수 추출 성공: 10
# INFO:comment_logger:기사 ID 추출 성공: 0030013198058
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 6480000035513
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:출판사 필터링 제외: 비즈워치
# INFO:comment_logger:기사 ID 추출 성공: 0030013197871
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008206785
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "모바일신분증 성과" 라온시큐어, 정보통신 유공 대통령 표창
# INFO:comment_logger:기사 ID 추출 성공: 0290002949728
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 2025 정보통신 유공 ‘대통령 표창’ 수상
# INFO:comment_logger:기사 ID 추출 성공: 0030013197788
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1380002195064
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 한싹, SSL 가시성 솔루션 '오스가드' 출시
# INFO:comment_logger:기사 ID 추출 성공: 0290002949708
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지니언스, 글로벌 보안 전시회 `RSAC 2025` 11년 연속 참가
# INFO:comment_logger:기사 ID 추출 성공: 1380002195061
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "AI 시대, 개인정보 정책 방향은?" 개인정보위, 미국 정부 만난다
# INFO:comment_logger:기사 ID 추출 성공: 0030013197696
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0290002949693
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 한싹, SSL 가시성 솔루션 ‘오스가드’ 출시
# INFO:comment_logger:기사 ID 추출 성공: 0110004476847
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 에티버스, 美 AI 기업 밴티크와 공동 사업 추진
# INFO:comment_logger:기사 ID 추출 성공: 1380002195058
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 미국으로 날아간 지니언스, EDR 포함 3대 솔루션 전시
# INFO:comment_logger:기사 ID 추출 성공: 1380002195057
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "보안사업 확대" KG ICT, 넷앤드와 전략파트너 계약
# INFO:comment_logger:기사 ID 추출 성공: 0290002949682
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 하나저축은행, 디지털뱅킹 보안 고도화 위해 `페이크파인더` 도입
# INFO:comment_logger:기사 ID 추출 성공: 0030013197579
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 한싹, SSL 가시성 솔루션 '오스가드' 출시
# INFO:comment_logger:기사 ID 추출 성공: 4210008206564
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013197521
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013197490
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 스틸리언-법무법인 세종, 금융보안·법률자문 역량 맞손
# INFO:comment_logger:기사 ID 추출 성공: 0030013197474
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 정보통신 유공 '대통령 표창' 수상…보안·인증 산업 혁신 공로
# INFO:comment_logger:기사 ID 추출 성공: 4210008206404
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지니언스 보안판 CES 'RSA 콘퍼런스'서 네트워크·단말 보안 소개
# INFO:comment_logger:기사 ID 추출 성공: 0030013197384
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지니언스, RSAC 2025 참가…글로벌 무대서 통합 보안 전략 제시
# INFO:comment_logger:기사 ID 추출 성공: 0140005339242
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지니언스, 'RSA 2025' 11년 연속 참가.. 글로벌 시장 겨냥
# INFO:comment_logger:기사 ID 추출 성공: 0110004476759
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 클라우드 확장 '메타넷티플랫폼', 매출액 5000억 돌파
# INFO:comment_logger:기사 ID 추출 성공: 0300003305513
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 모코엠시스, 정보통신망 정보보호 콘퍼런스 참가...최신 문서 보안 동향 강연
# INFO:comment_logger:20개의 기사가 필터링되어 저장됩니다.
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 7개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015345379] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015345379] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015345379] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015345379] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 40개 버튼 클릭 성공
# INFO:comment_logger:대댓글 37개 버튼 클릭 성공
# INFO:comment_logger:대댓글 9개 버튼 클릭 성공
# INFO:comment_logger:대댓글 7개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 4개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477079] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:[1380002195097] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[1380002195097] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[1380002195097] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[1380002195097] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 4개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:[0030013198106] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013198106] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013198106] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:[4210008207080] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[4210008207080] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[4210008207080] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[4210008207080] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[4210008207080] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:20250423 날짜로 크롤링 시작
# INFO:comment_logger:크롤링 시작: https://news.naver.com/breakingnews/section/105/732?date=20250423
# INFO:comment_logger:기사 더보기 클릭 성공
# INFO:comment_logger:더 이상 기사 더보기 버튼이 없습니다.
# INFO:comment_logger:총 43개의 기사 로드 완료
# INFO:comment_logger:기사 ID 추출 성공: 0290002950256
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: [오늘의 DT인] 내부조직 혁신 본격화… "2027년까지 전 직원 10% AI 전문가로 육성"
# INFO:comment_logger:기사 ID 추출 성공: 0010015347819
# INFO:comment_logger:댓글 수 추출 성공: 50
# INFO:comment_logger:키워드 필터링 제외: 선관위 "선거통계시스템에 사이버공격 확인…경찰에 수사 의뢰"
# INFO:comment_logger:기사 ID 추출 성공: 0290002950225
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 1분기 피싱 문자 1위는 `기관 사칭`…단기 알바 위장도 급증
# INFO:comment_logger:기사 ID 추출 성공: 0030013202086
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 징글징글한 스미싱…10개중 3개가 '이것' 사칭
# INFO:comment_logger:기사 ID 추출 성공: 1380002195185
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: “개별 솔루션 시대 저물다” 파고네트웍스, AI 통합보안 플랫폼 전략 공개
# INFO:comment_logger:기사 ID 추출 성공: 0030013201995
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 보안업계가 새 정부에 바란다…정보보호산업발전자문위 개최
# INFO:comment_logger:기사 ID 추출 성공: 0010015347691
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: AI로 만든 아동 성 착취물 급증…훨씬 더 정교해졌다
# INFO:comment_logger:기사 ID 추출 성공: 0310000926931
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 파수, 'FDI 2025 심포지엄' 성료…"보안부터 생성형 AI 활용까지 지원"
# INFO:comment_logger:기사 ID 추출 성공: 0010015347546
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: [게시판] 디지털 신원 지갑 등 분야 국제표준 주도권 확보
# INFO:comment_logger:기사 ID 추출 성공: 1380002195177
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 이형욱 F5코리아 지사장 "AI 기반 애플리케이션 보안, 전례 없는 과제 직면"
# INFO:comment_logger:기사 ID 추출 성공: 4210008210457
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0110004477505
# INFO:comment_logger:댓글 수 추출 성공: 30
# INFO:comment_logger:기사 ID 추출 성공: 1380002195172
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 박상원 신임 금융보안원장 "보안 넥스트레벨 선도하겠다"
# INFO:comment_logger:기사 ID 추출 성공: 0300003306278
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 디지털 지갑·제로 트러스트 등 한국 제안 기술 국제표준 승인
# INFO:comment_logger:기사 ID 추출 성공: 0010015347087
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 윈도우10 기술지원 10월 종료…과기부, 대응 종합상황실 운영
# INFO:comment_logger:기사 ID 추출 성공: 0300003306267
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: '고수익 단기 알바' 피싱 문자 급증…안랩, 1분기 보고서 발표
# INFO:comment_logger:기사 ID 추출 성공: 0300003306258
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 파고네트웍스, 통합보안 플랫폼 '딥액트' 출시…“사이버위협 최전선서 대응”
# INFO:comment_logger:기사 ID 추출 성공: 0300003306181
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 시큐다임, 중기부 유망 중소기업 선정
# INFO:comment_logger:기사 ID 추출 성공: 4210008209835
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0290002950095
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 파수, ‘FDI 2025’ 개최…“보안부터 AI까지 전방위 지원“
# INFO:comment_logger:기사 ID 추출 성공: 0030013200821
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0300003306124
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: [WIS 2025] 제타큐브, 초소형 디핀 데이터센터 'NANODC'
# INFO:comment_logger:기사 ID 추출 성공: 0300003306120
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: “윈도10 기술지원 종료 임박”…과기정통부, 종합상황실 운영
# INFO:comment_logger:기사 ID 추출 성공: 0140005340035
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 과기정통부, 윈도10 기술지원 종료 대응 위해 종합상황실 운영
# INFO:comment_logger:기사 ID 추출 성공: 4210008209689
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "디지털 신원지갑·제로트러스트" 韓 보안 표준항목 글로벌 승인
# INFO:comment_logger:기사 ID 추출 성공: 4210008209675
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 과기부·KISA, 윈도우10 기술지원 종료 대비 종합상황실 운영
# INFO:comment_logger:기사 ID 추출 성공: 0030013200755
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: '바둑 천재' 이세돌 "AI 시대 인간의 가치는"…내일 초청 강연
# INFO:comment_logger:기사 ID 추출 성공: 0030013200742
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 韓 디지털 신원지갑·제로트러스트 등 국제표준 승인
# INFO:comment_logger:기사 ID 추출 성공: 0150005122900
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 나도 쉽게 당할 수 있다…문자 피싱 유형 1위는 ‘이것’
# INFO:comment_logger:기사 ID 추출 성공: 1380002195138
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0010015346243
# INFO:comment_logger:댓글 수 추출 성공: 50
# INFO:comment_logger:키워드 필터링 제외: '남자가 여자화장실 들어가면 알람'…안양시 성별인식 CCTV 확대
# INFO:comment_logger:기사 ID 추출 성공: 4210008209181
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0010015346187
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩 "1분기 피싱 문자 4건 중 1건은 정부·공공기관 사칭"
# INFO:comment_logger:기사 ID 추출 성공: 0140005339954
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 파수, ‘FDI 2025 심포지엄’ 성료.. "글로벌 AI 보안 기업으로"
# INFO:comment_logger:기사 ID 추출 성공: 1380002195128
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "단기알바 구하시죠?" 부업 인기에 피싱 문자 285% '쑥'
# INFO:comment_logger:기사 ID 추출 성공: 1380002195123
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "자동 로그인, 편하지만 정보노출 위험" KISA, 크롬 취약점 패치 권고
# INFO:comment_logger:기사 ID 추출 성공: 0300003305989
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:출판사 필터링 제외: 전자신문
# INFO:comment_logger:기사 ID 추출 성공: 0300003305983
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KISA, 크롬 브라우저 최신 패치 적용 권고…“자동로그인 취약점 개선”
# INFO:comment_logger:기사 ID 추출 성공: 0010015345903
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KISA, 크롬 브라우저 업그레이드 권고…자동 로그인 취약점 개선
# INFO:comment_logger:기사 ID 추출 성공: 0140005339898
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KISA "크롬 브라우저 자동 로그인 취약점 패치 적용하세요"
# INFO:comment_logger:기사 ID 추출 성공: 4210008208907
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 구글 크롬 자동로그인 보안강화…"최신 패치 신속 적용"
# INFO:comment_logger:기사 ID 추출 성공: 0030013200006
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KISA, 크롬 브라우저 자동 로그인 취약점 패치 적용 권고
# INFO:comment_logger:기사 ID 추출 성공: 0110004477259
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: MSP 강자 '메가존클라우드', 양자컴퓨팅 관심 갖는 이유는
# INFO:comment_logger:6개의 기사가 필터링되어 저장됩니다.
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 3개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:[0110004477505] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477505] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477505] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477505] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477505] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477505] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0110004477505] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0110004477505] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:20250424 날짜로 크롤링 시작
# INFO:comment_logger:크롤링 시작: https://news.naver.com/breakingnews/section/105/732?date=20250424
# INFO:comment_logger:기사 더보기 클릭 성공
# INFO:comment_logger:더 이상 기사 더보기 버튼이 없습니다.
# INFO:comment_logger:총 53개의 기사 로드 완료
# INFO:comment_logger:기사 ID 추출 성공: 0030013205070
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개인정보 무단 국외이전한 딥시크…정부 '즉각 파기' 권고(종합)
# INFO:comment_logger:기사 ID 추출 성공: 1380002195298
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "심층 방어체계, 혼자서 만들 수 없다"…N²SF연구회 발족
# INFO:comment_logger:기사 ID 추출 성공: 0150005123786
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 딥시크, AI 질문 내용도 틱톡 계열사에 유출
# INFO:comment_logger:기사 ID 추출 성공: 0310000927362
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "반도체 소부장 기업 M&A로 기술·인력 中 유출 심각"
# INFO:comment_logger:기사 ID 추출 성공: 0110004478088
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: [단독] 美 AI 투자 400억 손실 출자자들, VC에 집단소송
# INFO:comment_logger:기사 ID 추출 성공: 1380002195290
# INFO:comment_logger:댓글 수 추출 성공: 30
# INFO:comment_logger:키워드 필터링 제외: [DD퇴근길] 김우빈 vs 손흥민 vs 뷔…저가커피 모델 승자는?
# INFO:comment_logger:기사 ID 추출 성공: 1380002195279
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013204106
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0300003306672
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 퀀텀코리아, NVMe 올플래시 VTL 'DXi T10' 국내 출시
# INFO:comment_logger:기사 ID 추출 성공: 0150005123544
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 'K-엑센츄어 표방' ISTN/INF 합병 추진…"올인원 E2E IT서비스 회사 거듭날 것"
# INFO:comment_logger:기사 ID 추출 성공: 1380002195263
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 아톤, CSAP 인증 ‘깃플챗K’ 나라장터 입성…“공공기관 AI상담 혁신 가속화”
# INFO:comment_logger:기사 ID 추출 성공: 0300003306646
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개인정보보호 시정조치 이행률 95.6%…메타·알리 등 글로벌기업도 이행
# INFO:comment_logger:기사 ID 추출 성공: 0300003306600
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 이글루코퍼레이션, 데이터 분석 정확도 높이는 AI 특허 취득
# INFO:comment_logger:기사 ID 추출 성공: 1190002948947
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0300003306599
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 소프트캠프, '재팬 IT 위크 스프링' 참가…“日시장 공략 박차”
# INFO:comment_logger:기사 ID 추출 성공: 0300003306596
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개인정보위, '개인정보 논란' 딥시크에 시정권고…“조만간 서비스 재개할 듯”
# INFO:comment_logger:기사 ID 추출 성공: 0110004477902
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: '앱 중단' 딥시크, 개인정보위에 백기…국내 시장 재침투 임박
# INFO:comment_logger:기사 ID 추출 성공: 0010015349305
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개보위, 딥시크 사전 실태점검 결과 발표
# INFO:comment_logger:기사 ID 추출 성공: 0010015349302
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개보위, 딥시크 사전 실태점검 결과 발표
# INFO:comment_logger:기사 ID 추출 성공: 0010015349299
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개보위, 딥시크 사전 실태점검 결과 발표
# INFO:comment_logger:기사 ID 추출 성공: 0010015349296
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개보위, 딥시크 사전 실태점검 결과 발표
# INFO:comment_logger:기사 ID 추출 성공: 0010015349308
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 330만명 개인정보 넘기고도 버티던 메타…소송패소에 삭제 나서
# INFO:comment_logger:기사 ID 추출 성공: 0010015349293
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개보위, 딥시크 사전 실태점검 결과 발표
# INFO:comment_logger:기사 ID 추출 성공: 1380002195256
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 딥시크에 칼 빼든 개인정보위…"국외 이전 이용자 정보, 즉각 파기"
# INFO:comment_logger:기사 ID 추출 성공: 4210008212391
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개인정보 유출 처벌받은 메타·알리…'권고 조치' 이행·계획 제출
# INFO:comment_logger:기사 ID 추출 성공: 0030013203633
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개인정보위, 시정조치 이행률 95.6%…메타·알리 이행 완료
# INFO:comment_logger:기사 ID 추출 성공: 0030013203629
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개인정보 무단 국외이전한 딥시크…정부 '즉각 파기' 시정 권고
# INFO:comment_logger:기사 ID 추출 성공: 0300003306590
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:출판사 필터링 제외: 전자신문
# INFO:comment_logger:기사 ID 추출 성공: 0300003306589
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩블록체인컴퍼니, 차세대 디지털 기술 인재 양성 위한 다자간 MOU
# INFO:comment_logger:기사 ID 추출 성공: 1380002195255
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 일본으로 떠난 소프트캠프, 웹격리 보안 서비스 '실드게이트' 소개
# INFO:comment_logger:기사 ID 추출 성공: 4210008212171
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 삼성SDS, 1분기 영업이익 19%증가…클라우드·물류플랫폼 견인
# INFO:comment_logger:기사 ID 추출 성공: 0290002950418
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 코난테크놀로지, 신종 보이스피싱 AI로 잡는다…78억 규모 국책과제 선정
# INFO:comment_logger:기사 ID 추출 성공: 0290002950413
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 이글루코퍼레이션, 데이터 분석 정확도 높이는 AI 특허 취득
# INFO:comment_logger:기사 ID 추출 성공: 4210008212142
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: IBM "정보탈취 악성코드 이메일 84%증가…신원탈취 공격 급증"
# INFO:comment_logger:기사 ID 추출 성공: 0290002950409
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩블록체인컴퍼니, 차세대 디지털 기술 인재 양성 위한 다자간 MOU 체결
# INFO:comment_logger:기사 ID 추출 성공: 0030013203370
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 소프트캠프, 日 최대 IT전시회 '재팬 IT 위크 스프링' 참가
# INFO:comment_logger:기사 ID 추출 성공: 0030013203335
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩블록체인컴퍼니, 차세대 디지털 기술 인재 키운다
# INFO:comment_logger:기사 ID 추출 성공: 0030013203331
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 이글루코퍼레이션, 데이터 분석 정확도 높이는 AI 특허 취득
# INFO:comment_logger:기사 ID 추출 성공: 0010015348918
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008211866
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0110004477843
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 스카이월드와이드, '사이버범죄 단서 분석' 국책과제 참여
# INFO:comment_logger:기사 ID 추출 성공: 0140005340627
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩블록체인컴퍼니, 차세대 디지털 기술 인재 양성 위한 MOU 체결
# INFO:comment_logger:기사 ID 추출 성공: 0140005340594
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 소프트캠프, 일본 최대 IT 전시회 'Japan IT Week Spring' 참가
# INFO:comment_logger:기사 ID 추출 성공: 0010015348550
# INFO:comment_logger:댓글 수 추출 성공: 50
# INFO:comment_logger:기사 ID 추출 성공: 0030013202858
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 국정원, 서울시 사이버보안 '미흡' 평가…시 "개선 방안 마련"
# INFO:comment_logger:기사 ID 추출 성공: 0140005340537
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 포티넷코리아, '2024 지속가능성 보고서' 발표
# INFO:comment_logger:기사 ID 추출 성공: 0140005340525
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 이글루코퍼레이션, 데이터 분석 정확도 높이는 AI 특허 취득
# INFO:comment_logger:기사 ID 추출 성공: 1380002195212
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "데이터 분석 정확도↑" 이글루코퍼레이션, AI 특허 취득
# INFO:comment_logger:기사 ID 추출 성공: 0300003306454
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 시큐아이, 보험사 대상 AI 기반 금융 보안 전략 제시
# INFO:comment_logger:기사 ID 추출 성공: 1380002195202
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008211173
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013202445
# INFO:comment_logger:댓글 수 추출 성공: 10
# INFO:comment_logger:기사 ID 추출 성공: 0010015348149
# INFO:comment_logger:댓글 수 추출 성공: 100
# INFO:comment_logger:10개의 기사가 필터링되어 저장됩니다.
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 11개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 5개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015348550] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348550] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 5개 버튼 클릭 성공
# INFO:comment_logger:[0030013202445] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013202445] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013202445] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013202445] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013202445] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013202445] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013202445] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013202445] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013202445] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013202445] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 4개 버튼 클릭 성공
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015348149] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015348149] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:20250425 날짜로 크롤링 시작
# INFO:comment_logger:크롤링 시작: https://news.naver.com/breakingnews/section/105/732?date=20250425
# INFO:comment_logger:기사 더보기 클릭 성공
# INFO:comment_logger:더 이상 기사 더보기 버튼이 없습니다.
# INFO:comment_logger:총 53개의 기사 로드 완료
# INFO:comment_logger:기사 ID 추출 성공: 0010015352991
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0010015352972
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0010015352704
# INFO:comment_logger:댓글 수 추출 성공: 50
# INFO:comment_logger:기사 ID 추출 성공: 0110004478541
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008215441
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 에스원 1Q 영업익 550.5억원…전년 대비 13% 증가
# INFO:comment_logger:기사 ID 추출 성공: 4210008215352
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1380002195348
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 아카마이, ‘제로트러스트 & API 보안’ 세미나 개최… 금융권 보안 전략 제시
# INFO:comment_logger:기사 ID 추출 성공: 0030013206522
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206521
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206520
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206519
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206518
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206514
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206512
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206511
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206509
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206508
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206507
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206506
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206505
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206504
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206503
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206502
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206501
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206500
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206498
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206497
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206496
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206495
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206494
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206493
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008214923
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013206358
# INFO:comment_logger:댓글 수 추출 성공: 10
# INFO:comment_logger:기사 ID 추출 성공: 1380002195338
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 스콥정보통신, ‘2025 파트너스데이’ 개최… 파트너 협력 강화
# INFO:comment_logger:기사 ID 추출 성공: 1380002195334
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 넷앤드, 금융권 망분리 규제 개선과 클라우드 환경 대비 보안 전략 제시
# INFO:comment_logger:기사 ID 추출 성공: 1190002949486
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008214699
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008214692
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1190002949468
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 6480000035633
# INFO:comment_logger:댓글 수 추출 성공: 50
# INFO:comment_logger:출판사 필터링 제외: 비즈워치
# INFO:comment_logger:기사 ID 추출 성공: 0150005124032
# INFO:comment_logger:댓글 수 추출 성공: 50
# INFO:comment_logger:기사 ID 추출 성공: 0110004478381
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008214439
# INFO:comment_logger:댓글 수 추출 성공: 50
# INFO:comment_logger:기사 ID 추출 성공: 0030013205863
# INFO:comment_logger:댓글 수 추출 성공: 100
# INFO:comment_logger:기사 ID 추출 성공: 0300003306996
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 국방정보통신협회, '국방C4I체계 고도화 발전세미나' 성황리 개최
# INFO:comment_logger:기사 ID 추출 성공: 1380002195310
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "지난해 기초자치단체 개인정보 보호 미흡…공기업은 우수"
# INFO:comment_logger:기사 ID 추출 성공: 0010015351337
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개인정보 관리 최우수기관에 복지부·강원도·건보공단 등 선정
# INFO:comment_logger:기사 ID 추출 성공: 0030013205634
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 공공기관 개인정보 보호 수준 첫 평가…공기업 '우수' 기초지자체 '미흡'
# INFO:comment_logger:기사 ID 추출 성공: 0030013205590
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩, '재팬 IT 위크 스프링' 참가…글로벌 전략 솔루션 소개
# INFO:comment_logger:기사 ID 추출 성공: 0300003306972
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지케스 “K 방역 성공 가격·기술 덕택...'M 클라우드'로 K 보안 성공 이끌 것”
# INFO:comment_logger:기사 ID 추출 성공: 0140005341183
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩, 일본 최대 IT 전시회 ‘Japan IT Week Spring 2025’ 참가
# INFO:comment_logger:기사 ID 추출 성공: 0010015351089
# INFO:comment_logger:댓글 수 추출 성공: 10
# INFO:comment_logger:기사 ID 추출 성공: 0010015351000
# INFO:comment_logger:댓글 수 추출 성공: 300
# INFO:comment_logger:41개의 기사가 필터링되어 저장됩니다.
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 10개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015352704] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:[0030013206358] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013206358] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013206358] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013206358] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013206358] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013206358] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013206358] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013206358] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 3개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:[0150005124032] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0150005124032] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0150005124032] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0150005124032] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0150005124032] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0150005124032] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0150005124032] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0150005124032] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0150005124032] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0150005124032] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0150005124032] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0150005124032] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0150005124032] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0150005124032] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0150005124032] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0150005124032] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 3개 버튼 클릭 성공
# INFO:comment_logger:[4210008214439] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[4210008214439] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[4210008214439] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[4210008214439] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[4210008214439] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[4210008214439] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[4210008214439] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[4210008214439] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[4210008214439] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[4210008214439] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:댓글 더보기 클릭 성공
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 5개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:대댓글 8개 버튼 클릭 성공
# INFO:comment_logger:대댓글 7개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0030013205863] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0030013205863] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:[0010015351089] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015351089] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015351089] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015351089] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015351089] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015351089] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015351089] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015351089] 클린봇 필터된 댓글 감지, 건너뜀
# ...
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:대댓글 2개 버튼 클릭 성공
# INFO:comment_logger:[0010015379974] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015379974] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015379974] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015379974] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[0010015379974] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015379974] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015379974] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015379974] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[0010015379974] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:20250512 날짜로 크롤링 시작
# INFO:comment_logger:크롤링 시작: https://news.naver.com/breakingnews/section/105/732?date=20250512
# INFO:comment_logger:기사 더보기 클릭 성공
# INFO:comment_logger:더 이상 기사 더보기 버튼이 없습니다.
# INFO:comment_logger:총 49개의 기사 로드 완료
# INFO:comment_logger:기사 ID 추출 성공: 0150005130876
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "지도 넘기면 기술도 주권도 뺏긴다"…산업계 흔드는 지도 반출 논란
# INFO:comment_logger:기사 ID 추출 성공: 0110004484346
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0310000931518
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:출판사 필터링 제외: 아이뉴스24
# INFO:comment_logger:기사 ID 추출 성공: 1190002955212
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008245408
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0010015383432
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0290002953999
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개인정보위, 에너지 마이데이터 전송체계 실증 사업 공모
# INFO:comment_logger:기사 ID 추출 성공: 4210008245281
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1380002196363
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 이글루코퍼레이션, 1분기 매출 234억원…'AI XDR' 효과로 9.6%↑
# INFO:comment_logger:기사 ID 추출 성공: 4210008245105
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지니언스, 국내외 사이버 위협분석 집대성 보고서 영문 발간
# INFO:comment_logger:기사 ID 추출 성공: 1380002196361
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 선관위 사이버 공격, 외부 침입 없었다…'보안점검 착오' 결론
# INFO:comment_logger:기사 ID 추출 성공: 0300003311530
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지니언스, 위협 분석 보고서 영문판 정식 발간
# INFO:comment_logger:기사 ID 추출 성공: 0300003311528
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: “양자 컴퓨팅 시대 대비한다”…포티넷코리아, '이중 방어 보안 전략' 발표
# INFO:comment_logger:기사 ID 추출 성공: 0300003311523
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어-우연컴퍼니, 반려동물 디지털 신원증명·증명발급 '맞손'
# INFO:comment_logger:기사 ID 추출 성공: 0010015382822
# INFO:comment_logger:댓글 수 추출 성공: 30
# INFO:comment_logger:키워드 필터링 제외: 사이버공격 당했다던 선관위, 확인해보니 보안업체 점검중 착오
# INFO:comment_logger:기사 ID 추출 성공: 0300003311493
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩, 국제 사이버 공격 방어 연합훈련 '락드 쉴즈 2025' 참가
# INFO:comment_logger:기사 ID 추출 성공: 1380002196341
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 우연컴퍼니와 반려동물 디지털 신원증명 협력
# INFO:comment_logger:기사 ID 추출 성공: 0110004484196
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1380002196336
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: [NSIS 2025③] 단순 '철학'은 옛말, 걸음마 뗀 제로트러스트 보안
# INFO:comment_logger:기사 ID 추출 성공: 1190002955042
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008244360
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0010015382511
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 에너지 분야 마이데이터 지원사업 공모…총 13억원 지원
# INFO:comment_logger:기사 ID 추출 성공: 1380002196331
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 에너지 분야 '마이데이터 중계 실증 지원사업' 추진
# INFO:comment_logger:기사 ID 추출 성공: 0030013235819
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 개인정보위, 마이데이터 확대 '착착'…에너지 분야도 전송체계 마련
# INFO:comment_logger:기사 ID 추출 성공: 1190002955028
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1380002196319
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩, 국제 사이버방어 연합 훈련 '락드쉴즈' 참가
# INFO:comment_logger:기사 ID 추출 성공: 4210008244128
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013235414
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지니언스, 위협 분석 보고서 영문판 발간…'K-사이버 보안' 글로벌 확산
# INFO:comment_logger:기사 ID 추출 성공: 0110004484133
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: '위믹스 재상폐' 결국 소송전으로…법원에 가처분 신청
# INFO:comment_logger:기사 ID 추출 성공: 0290002953818
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩, 국제 사이버 공격 방어 연합훈련 ‘락드 쉴즈 2025’ 참가
# INFO:comment_logger:기사 ID 추출 성공: 1380002196301
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 주니퍼 네트웍스, 차세대 AI 네이티브 혁신 제공
# INFO:comment_logger:기사 ID 추출 성공: 0290002953817
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지니언스, 위협 분석 보고서 영문판 발간
# INFO:comment_logger:기사 ID 추출 성공: 1380002196298
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "국경 넘나드는 보안 위협" 지니언스, 영문판 위협분석 보고서 발간
# INFO:comment_logger:기사 ID 추출 성공: 4210008243799
# INFO:comment_logger:댓글 수 추출 성공: 10
# INFO:comment_logger:기사 ID 추출 성공: 4210008243789
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KT클라우드, 클로벌 최대 사이버 방어 훈련 '락드쉴즈2025' 참가
# INFO:comment_logger:기사 ID 추출 성공: 0110004484100
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: LG CNS "신한銀 AI, 챗GPT로 업그레이드"
# INFO:comment_logger:기사 ID 추출 성공: 1380002196295
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 금융보안원, NATO 주관 '락드쉴드 2025' 4년 연속 참가
# INFO:comment_logger:기사 ID 추출 성공: 1190002954913
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008243778
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013235152
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩, NATO 주관 국제 사이버 공격 방어 연합훈련 '락드 쉴즈 2025' 참가
# INFO:comment_logger:기사 ID 추출 성공: 1380002196293
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 피앤피시큐어, 2년 연속 '제로트러스트 시범사업' 선정
# INFO:comment_logger:기사 ID 추출 성공: 0030013235137
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 우연컴퍼니와 '맞손'…반려동물 디지털 신분증 시대 연다
# INFO:comment_logger:기사 ID 추출 성공: 4210008243735
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "블록체인으로 반려동물 신원인증"…라온시큐어·우연컴퍼니 협력
# INFO:comment_logger:기사 ID 추출 성공: 0010015381879
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KT클라우드, NATO 사이버방위센터 주관 훈련 '락드쉴즈' 참가
# INFO:comment_logger:기사 ID 추출 성공: 0140005347984
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어-우연컴퍼니, 반려동물 디지털 신원증명·증명발급 MOU
# INFO:comment_logger:기사 ID 추출 성공: 1190002954871
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: kt cloud, 글로벌 최대 사이버 방어 훈련 '락드쉴즈 2025' 참여
# INFO:comment_logger:기사 ID 추출 성공: 0140005347978
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩, 국제 사이버 공격 방어 연합훈련 ‘락드 쉴즈 2025’ 참가
# INFO:comment_logger:기사 ID 추출 성공: 0140005347969
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 지니언스, '위협 분석 보고서' 영문판 발간
# INFO:comment_logger:기사 ID 추출 성공: 4210008243323
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: [기자의눈]소비자에게만 깐깐한 가입 약관과 '기울어진 운동장'
# INFO:comment_logger:13개의 기사가 필터링되어 저장됩니다.
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:대댓글 1개 버튼 클릭 성공
# INFO:comment_logger:[4210008243799] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:[4210008243799] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[4210008243799] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[4210008243799] 댓글/답글 본문 없음, 건너뜀
# INFO:comment_logger:20250513 날짜로 크롤링 시작
# INFO:comment_logger:크롤링 시작: https://news.naver.com/breakingnews/section/105/732?date=20250513
# INFO:comment_logger:더 이상 기사 더보기 버튼이 없습니다.
# INFO:comment_logger:총 21개의 기사 로드 완료
# INFO:comment_logger:기사 ID 추출 성공: 0110004484844
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: AI 사업도 재편성…SK C&C→SK AX로 사명 변경
# INFO:comment_logger:기사 ID 추출 성공: 1380002196483
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KSII·KIoT·KSAEM, 학술교류·사업협력 양해각서 체결
# INFO:comment_logger:기사 ID 추출 성공: 0290002954322
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩, 경북지역 산불 피해 복구 위해 기부금 전달
# INFO:comment_logger:기사 ID 추출 성공: 1380002196469
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: '네트워크 보안 강자' 엑스게이트, 양자로 퀀텀점프…"보안 고도화 집중"
# INFO:comment_logger:기사 ID 추출 성공: 0300003312055
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 시큐어시스템즈, 역대 최대 규모 NATO 국제 사이버훈련 '락드 쉴즈 2025' 참가
# INFO:comment_logger:기사 ID 추출 성공: 0150005131271
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0290002954289
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:출판사 필터링 제외: 디지털타임스
# INFO:comment_logger:기사 ID 추출 성공: 0110004484751
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: SK C&C. SK AX로 사명 변경…SK그룹 AI 사업 구조 전면 개편
# INFO:comment_logger:기사 ID 추출 성공: 1190002955655
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0010015385478
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0300003311857
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: “경북 산불 피해 복구”…안랩, 굿피플 대구경북지부에 기부금 전달
# INFO:comment_logger:기사 ID 추출 성공: 0300003311828
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 로그프레소, AI스페라·엑소스피어랩스와 SaaS 기반 XDR 공동개발
# INFO:comment_logger:기사 ID 추출 성공: 1380002196414
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 팔로알토네트웍스, AI 보안 플랫폼 '프리즈마 에어즈' 출시
# INFO:comment_logger:기사 ID 추출 성공: 0010015384214
# INFO:comment_logger:댓글 수 추출 성공: 10
# INFO:comment_logger:키워드 필터링 제외: 美기업 원격 위장취업 北 사이버요원들, 구글·보안기업도 노려
# INFO:comment_logger:기사 ID 추출 성공: 1380002196408
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 'SaaS 기반 XDR' 공동 개발하는 국내 보안기업 어디?
# INFO:comment_logger:기사 ID 추출 성공: 1380002196407
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: [NSIS 2025④] 신(新)보안체계 서막…공공·금융 망분리 완화 시동
# INFO:comment_logger:기사 ID 추출 성공: 0140005348623
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 안랩, 경북 산불 피해 복구 위해 굿피플 대구경북지부에 기부금 전달
# INFO:comment_logger:기사 ID 추출 성공: 1380002196396
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1380002196395
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1190002955348
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: TTA, 캐릭터 저작물 공정사용 위한 메타데이터 표준화 추진
# INFO:comment_logger:기사 ID 추출 성공: 0110004484523
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 결제·기술 부문 호조…NHN, 1분기 영업이익 276억원
# INFO:comment_logger:5개의 기사가 필터링되어 저장됩니다.
# INFO:comment_logger:20250514 날짜로 크롤링 시작
# INFO:comment_logger:크롤링 시작: https://news.naver.com/breakingnews/section/105/732?date=20250514
# INFO:comment_logger:기사 더보기 클릭 성공
# INFO:comment_logger:더 이상 기사 더보기 버튼이 없습니다.
# INFO:comment_logger:총 43개의 기사 로드 완료
# INFO:comment_logger:기사 ID 추출 성공: 4210008250958
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 파수 1분기 적자 규모 확대…매출 전년비 3.6%증가
# INFO:comment_logger:기사 ID 추출 성공: 1380002196588
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0110004485323
# INFO:comment_logger:댓글 수 추출 성공: 10
# INFO:comment_logger:키워드 필터링 제외: 상폐 칼날 휘두르는 코인 거래소 연합…신산업 앞길까지 막는다
# INFO:comment_logger:기사 ID 추출 성공: 1380002196585
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 국방혁신기술보안협회-육군사관학교, ‘AI 기반 국방력 강화를 위한 합동 세미나’ 개최
# INFO:comment_logger:기사 ID 추출 성공: 1190002956221
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 4210008250629
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0300003312457
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:출판사 필터링 제외: 전자신문
# INFO:comment_logger:기사 ID 추출 성공: 0140005349495
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 소프트캠프, 'AWS 서밋 서울 2025' 참가
# INFO:comment_logger:기사 ID 추출 성공: 0300003312408
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 소프트캠프, 'AWS 서밋 서울' 참가
# INFO:comment_logger:기사 ID 추출 성공: 0030013241512
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0300003312370
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 정보보호 정책교류 목말랐다…전국정보보호정책협의회 회원기관 360여곳 확보
# INFO:comment_logger:기사 ID 추출 성공: 4210008250016
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1380002196544
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: [NSIS 2025⑤] 기존 암호체계의 붕괴? 보안업계 '양자' 뜨거운 관심
# INFO:comment_logger:기사 ID 추출 성공: 1380002196543
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 소프트캠프, 'AWS 서밋 서울' 참가
# INFO:comment_logger:기사 ID 추출 성공: 0300003312313
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 사이버아크, 제레미 심 APJ 지역 채널담당 부사장 임명
# INFO:comment_logger:기사 ID 추출 성공: 0300003312308
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 파고네트웍스, 사이버엑스센터와 전략적 파트너십…“OT 보안 역량 강화”
# INFO:comment_logger:기사 ID 추출 성공: 0300003312305
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 엔시큐어 '엔젠오네스 v2.0', 조달청 디지털서비스몰 등록
# INFO:comment_logger:기사 ID 추출 성공: 1190002956069
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KT, ‘안심 QR’ 기능 아이폰으로 확대…피싱 범죄 실시간 차단
# INFO:comment_logger:기사 ID 추출 성공: 1380002196535
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1190002956020
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013240795
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 오내피플, 한국형 통합보안 모델 개발 시범사업 최종 선정
# INFO:comment_logger:기사 ID 추출 성공: 4210008249447
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: "AI 악용 악성코드 방어할 전문가 육성"…KISIA 교육생 모집
# INFO:comment_logger:기사 ID 추출 성공: 0150005131666
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0030013240758
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 日 생체인증 서비스 '터치엔 원패스' MAU 700만 돌파
# INFO:comment_logger:기사 ID 추출 성공: 4210008249369
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 0300003312202
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 日 생체인증서비스 MAU 700만 돌파
# INFO:comment_logger:기사 ID 추출 성공: 0010015387146
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: SK그룹, 정보보호 특별위원회 신설…위원장에 최창원 의장
# INFO:comment_logger:기사 ID 추출 성공: 1380002196515
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 日 생체인증 서비스 '터치엔 원패스' MAU 700만 돌파
# INFO:comment_logger:기사 ID 추출 성공: 0110004485086
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 적자폭 줄였지만 갈 길 먼 위메이드…1Q 적자 113억원
# INFO:comment_logger:기사 ID 추출 성공: 1380002196505
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 푸마, 워크데이 도입으로 인사관리 체계 강화
# INFO:comment_logger:기사 ID 추출 성공: 0140005349252
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 日 생체인증서비스 MAU 700만 돌파
# INFO:comment_logger:기사 ID 추출 성공: 0010015386769
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어, 생체인증 서비스 일본 월간활성이용자 700만 돌파
# INFO:comment_logger:기사 ID 추출 성공: 0030013240264
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:기사 ID 추출 성공: 1380002196499
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 엔시큐어, 서비스 장애 관리 솔루션 '엔젠오네스 v2.0' 조달청 등록
# INFO:comment_logger:기사 ID 추출 성공: 0150005131593
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 카카오엔터, 월 방문자 1000만회 괴물 불법 웹툰·웹소설 사이트 폐쇄
# INFO:comment_logger:기사 ID 추출 성공: 4210008248879
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KT, B2B 보안 서비스 클린존·AI메일보안 고도화나선다
# INFO:comment_logger:기사 ID 추출 성공: 4210008248878
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 라온시큐어 "日생체인증서비스 MAU 700만 돌파…연내 천만달성"
# INFO:comment_logger:기사 ID 추출 성공: 1380002196498
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: 사이버아크, 제레미 심 APJ 지역 채널담당 부사장 임명
# INFO:comment_logger:기사 ID 추출 성공: 1380002196496
# INFO:comment_logger:댓글 수 추출 성공: 10
# INFO:comment_logger:기사 ID 추출 성공: 0010015386668
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KT "디도스 방어 설루션·위협메일 차단 서비스 고도화"
# INFO:comment_logger:기사 ID 추출 성공: 0010015386608
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KT, 안전한 디지털 환경 구축 나선다
# INFO:comment_logger:기사 ID 추출 성공: 0010015386607
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KT, 안전한 디지털 환경 구축 나선다
# INFO:comment_logger:기사 ID 추출 성공: 0010015386606
# INFO:comment_logger:댓글 수 없음
# INFO:comment_logger:키워드 필터링 제외: KT, 안전한 디지털 환경 구축 나선다
# INFO:comment_logger:11개의 기사가 필터링되어 저장됩니다.
# INFO:comment_logger:댓글 버튼 클릭 성공!
# INFO:comment_logger:더 이상 댓글 더보기 버튼이 없습니다.
# INFO:comment_logger:[1380002196496] 클린봇 필터된 댓글 감지, 건너뜀
# INFO:comment_logger:[1380002196496] 댓글/답글 본문 없음, 건너뜀
# MySQL 백업 성공: backups/backup_20250515.sql
